# %%
import csv

# %%
import pandas as pd

# %%
import numpy as np

# %%
temp = pd.read_csv('Base de Datos Planta pH/Clarke_DataSet.csv', index_col=0)

# %%
temp.head()
# Out:
#           KS      AD   SW        WX       Fit       TIC  Willmott  Russell_Pr  \
# Model_No
# 1          0  0.0005  0.0  0.279529  0.917823  0.041132  0.942422    0.026184
# 2          0  0.0005  0.0  0.294311  0.921660  0.039219  0.942625    0.024961
# 3          0  0.0000  0.0  0.000000      -inf  1.000000      -inf         inf
# 4          0  0.0005  0.0  0.299143  0.924268  0.037901  0.943230    0.024127
# 5          0  0.0005  0.0  0.293616  0.923102  0.038492  0.942821    0.024500
#
#           Russell_Mr     SG_Mr  ...          Tr          Ts        Mp  \
# Model_No                        ...
# 1          -0.001824 -0.002103  ...    9.832605   53.547765  3.424147
# 2          -0.002142 -0.002469  ...   30.037371   50.741562  0.259691
# 3                inf  1.000000  ...  542.696733  995.900121  0.000000
# 4          -0.001587 -0.001829  ...   27.367844   50.631888  1.106278
# 5          -0.001945 -0.002241  ...   29.537180   49.634504  0.302265
#
# ...
